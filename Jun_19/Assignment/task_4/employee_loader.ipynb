# %%
from pyspark.sql.functions import col

# %%
# 2 & 3. Create employee data and DataFrame
emp_data = [
    (1, "Guru Prasad", "Data Engineering", 85000),
    (2, "Ananya Rao", "Generative AI", 95000),
    (3, "Siddharth Singh", "DevOps", 75000),
    (4, "Meghana Reddy", "Data Engineering", 90000)
]
columns = ["emp_id", "name", "department", "salary"]
df_emp = spark.createDataFrame(emp_data, columns)

# %%
# 4. Display the DataFrame
display(df_emp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Guru Prasad</td><td>Data Engineering</td><td>85000</td></tr><tr><td>2</td><td>Ananya Rao</td><td>Generative AI</td><td>95000</td></tr><tr><td>3</td><td>Siddharth Singh</td><td>DevOps</td><td>75000</td></tr><tr><td>4</td><td>Meghana Reddy</td><td>Data Engineering</td><td>90000</td></tr></tbody></table></div>

# %%
# 5. Print completion tracking string
print("Employee Load Completed")
# Out:
# Employee Load Completed
