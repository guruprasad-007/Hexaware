# %%
df_target = spark.read.table("customer_table")

# %%
df_summary = df_target.groupBy("city").count()
display(df_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>count</th></tr></thead><tbody><tr><td>Hyderabad</td><td>2</td></tr><tr><td>Bangalore</td><td>2</td></tr><tr><td>Mumbai</td><td>1</td></tr></tbody></table></div>
