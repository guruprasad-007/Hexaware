# %%
# 2. Create customer DataFrame
cust_data = [
    (501, "Rahul", "Hyderabad"), (502, "Priya", "Bangalore"),
    (503, "Amit", "Mumbai"), (504, "Sneha", "Hyderabad"),
    (505, "Vikram", "Bangalore")
]
columns = ["customer_id", "customer_name", "city"]
df_cust = spark.createDataFrame(cust_data, columns)

# %%
# 3. Save it as a persistent managed delta table block
df_cust.write.mode("overwrite").saveAsTable("customer_table")
print("Target Customer table written successfully.")
# Out:
# Target Customer table written successfully.
